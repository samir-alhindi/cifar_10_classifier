# %%
import tensorflow as tf
import pandas as pd 
import numpy as np 
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

classes = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck"
}

# %%
for i in range(5):
    print(
        classes[y_train[i][0]]
    )
    plt.imshow(x_train[i])
    plt.show() # Display the image
# Out:
# frog
# truck
# truck
# deer
# automobile

# %%
model = keras.models.Sequential([
    keras.layers.Input( (32, 32, 3) ),
    
    keras.layers.Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2), 

    keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),

    keras.layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=2),

    keras.layers.Flatten(),
        
    keras.layers.Dense(10, activation='softmax'),
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, epochs=10, verbose=2)
# Out:
# Epoch 1/10
# 1563/1563 - 40s - 26ms/step - accuracy: 0.4437 - loss: 1.8137
# Epoch 2/10
# 1563/1563 - 37s - 24ms/step - accuracy: 0.5772 - loss: 1.2151
# Epoch 3/10
# 1563/1563 - 41s - 26ms/step - accuracy: 0.6285 - loss: 1.0802
# Epoch 4/10
# 1563/1563 - 41s - 26ms/step - accuracy: 0.6597 - loss: 0.9920
# Epoch 5/10
# 1563/1563 - 37s - 24ms/step - accuracy: 0.6820 - loss: 0.9248
# Epoch 6/10
# 1563/1563 - 37s - 24ms/step - accuracy: 0.6944 - loss: 0.8868
# Epoch 7/10
# 1563/1563 - 37s - 24ms/step - accuracy: 0.7162 - loss: 0.8310
# Epoch 8/10
# 1563/1563 - 37s - 24ms/step - accuracy: 0.7261 - loss: 0.8000
# Epoch 9/10
# 1563/1563 - 37s - 24ms/step - accuracy: 0.7362 - loss: 0.7735
# Epoch 10/10
# 1563/1563 - 37s - 24ms/step - accuracy: 0.7467 - loss: 0.7405

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6563 - loss: 1.0865
# [1.0939017534255981, 0.6553999781608582]
